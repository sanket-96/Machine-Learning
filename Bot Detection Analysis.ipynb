# %% [markdown]
# ### BOT Detection using Unsupervised Algorithm
#
# ### Problem Statement:- Determine the unique IP which is suspected to be BOT.

# %% [markdown]
# #### Load the important Libraries to perform task

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.graph_objs as go
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %%
df=pd.read_csv('ibm_data.csv',index_col=0)

# %%
df.head(10)
# Out:
#        ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0  United States      United States               North America
# 1          Japan              Japan                       Japan
# 2  United States      United States               North America
# 3         Brazil             Brazil               Latin America
# 4         France             France                      Europe
# 5  United States      United States               North America
# 6  United States      United States               North America
# 7          Japan              Japan                       Japan
# 8      Singapore              ASEAN                Asia Pacific
# 9          Japan              Japan                       Japan
#
#                      city          st         sec_lvl_domn  device_type  \
# 0                 SLIDELL   LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                   TOKYO       TOKYO           MOPERA.NET       TABLET
# 2               ELK GROVE  CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3  SAO FRANCISCO DE GOIAS       GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4                  BEZONS  VAL-D'OISE           PROXAD.NET  MOBILEPHONE
# 5              BURLINGTON  WASHINGTON          COMCAST.NET  MOBILEPHONE
# 6                   BURKE    VIRGINIA            MYVZW.COM  MOBILEPHONE
# 7             SHIMONOSEKI   YAMAGUCHI            OCN.NE.JP  MOBILEPHONE
# 8               SINGAPORE        NONE       SINGNET.COM.SG  MOBILEPHONE
# 9                   TOKYO       TOKYO         SO-NET.NE.JP       TABLET
#
#    operating_sys                                            ip_addr  \
# 0     IOS_12.1.4  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1    ANDROID_6.0  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2     IOS_12.1.2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3    ANDROID_6.0  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4      ANDROID_9  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
# 5     IOS_12.1.4  5e5f663d70a6473ac173b0d9e20313f8674eea512da420...
# 6  ANDROID_8.0.0  fdae22d793b0bc5bb646d085fcde85951f9436e3036420...
# 7    ANDROID_6.0  72d73da31afc11d990b9b1d7d4b156ae7fe06b320c8de2...
# 8       IOS_12.1  c9f1ab921424744dadd5ef2b91e18f8d159e8e15da5809...
# 9       IOS_11.3  3bce5d56cf4d80d0095f066b1a0ff2d7e6a4960748b234...
#
#                                           user_agent  VISIT  ENGD_VISIT  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...      1           0
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...      1           0
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...      1           0
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...      1           0
# 5  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           1
# 6  MOZILLA/5.0 (LINUX; ANDROID 8.0.0; SM-J737V) A...      6           0
# 7  MOZILLA/5.0 (LINUX; ANDROID 6.0; SO-01H) APPLE...      1           0
# 8  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1 LIKE M...      1           1
# 9  MOZILLA/5.0 (IPAD; CPU OS 11_3 LIKE MAC OS X) ...      1           0
#
#    VIEWS                                           page_url  wk  mth    yr  \
# 0      1                        www.ibm.com/watson/campaign  11    3  2019
# 1      1                          www.ibm.com/privacy/us/en  11    3  2019
# 2      1  www.ibm.com/account/reg/us-en/signup?formid=ur...  11    3  2019
# 3      1  www.ibm.com/analytics/br/pt/business-intelligence  11    3  2019
# 4      1                           www.ibm.com/watson/fr-fr  11    3  2019
# 5      1  careers.ibm.com/showjob/id/492873/user-researcher  11    3  2019
# 6     11               www.ibm.com/thought-leadership/smart  11    3  2019
# 7      1                                  www.ibm.com/jp-ja  11    3  2019
# 8      1            www.ibm.com/sg-en/analytics/spss-trials  11    3  2019
# 9      1             www.ibm.com/jp-ja/cloud/info/websphere  11    3  2019
#
#                    page_vw_ts
# 0  2019-06-04 05:05:18.023100
# 1  2019-06-04 05:07:11.014300
# 2  2019-06-04 05:08:46.081900
# 3  2019-06-04 05:07:22.033300
# 4  2019-06-04 05:05:27.027700
# 5  2019-06-04 05:14:33.085900
# 6  2019-06-04 05:12:12.017500
# 7  2019-06-04 05:14:32.081900
# 8  2019-06-04 05:14:02.013000
# 9  2019-06-04 05:10:04.070700

# %%
# Let's bring some statistical insights fro data
df.describe()
# Out:
#               VISIT    ENGD_VISIT         VIEWS         wk        mth  \
# count  1.048573e+06  1.048573e+06  1.048573e+06  1048573.0  1048573.0
# mean   1.108003e+00  3.440018e-01  1.410784e+00       11.0        3.0
# std    2.359586e+00  1.157801e+00  3.242692e+00        0.0        0.0
# min    1.000000e+00  0.000000e+00  1.000000e+00       11.0        3.0
# 25%    1.000000e+00  0.000000e+00  1.000000e+00       11.0        3.0
# 50%    1.000000e+00  0.000000e+00  1.000000e+00       11.0        3.0
# 75%    1.000000e+00  1.000000e+00  1.000000e+00       11.0        3.0
# max    1.195000e+03  6.940000e+02  1.196000e+03       11.0        3.0
#
#               yr
# count  1048573.0
# mean      2019.0
# std          0.0
# min       2019.0
# 25%       2019.0
# 50%       2019.0
# 75%       2019.0
# max       2019.0

# %%
# Let's check the inforamtion and type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048573 entries, 0 to 1048572
# Data columns (total 18 columns):
# ctry_name                      1048573 non-null object
# intgrtd_mngmt_name             1048573 non-null object
# intgrtd_operating_team_name    1048573 non-null object
# city                           1001987 non-null object
# st                             1003128 non-null object
# sec_lvl_domn                   729116 non-null object
# device_type                    206532 non-null object
# operating_sys                  1046753 non-null object
# ip_addr                        1048573 non-null object
# user_agent                     1048567 non-null object
# VISIT                          1048573 non-null int64
# ENGD_VISIT                     1048573 non-null int64
# VIEWS                          1048573 non-null int64
# page_url                       1048572 non-null object
# wk                             1048573 non-null int64
# mth                            1048573 non-null int64
# yr                             1048573 non-null int64
# page_vw_ts                     1045830 non-null object
# dtypes: int64(6), object(12)
# memory usage: 152.0+ MB

# %%
# check fro null values
df.isnull().sum()
# Out:
# ctry_name                           0
# intgrtd_mngmt_name                  0
# intgrtd_operating_team_name         0
# city                            46586
# st                              45445
# sec_lvl_domn                   319457
# device_type                    842041
# operating_sys                    1820
# ip_addr                             0
# user_agent                          6
# VISIT                               0
# ENGD_VISIT                          0
# VIEWS                               0
# page_url                            1
# wk                                  0
# mth                                 0
# yr                                  0
# page_vw_ts                       2743
# dtype: int64

# %%
import datetime
df['page_vw_ts']=pd.to_datetime(df['page_vw_ts'])

# %%
df.page_vw_ts.dt.dayofyear.head()
# Out:
# 0    155.0
# 1    155.0
# 2    155.0
# 3    155.0
# 4    155.0
# Name: page_vw_ts, dtype: float64

# %%
df['ip_addr']= df['ip_addr'].astype(str)
df['VISIT']= df['VISIT'].astype(int)
df['ENGD_VISIT']= df['ENGD_VISIT'].astype(int)
df['VIEWS']= df['VIEWS'].astype(int)
df['wk']= df['wk'].astype(int)

# %%
df['day']=df['page_vw_ts'].dt.weekday

# %%
df.head()
# Out:
#        ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0  United States      United States               North America
# 1          Japan              Japan                       Japan
# 2  United States      United States               North America
# 3         Brazil             Brazil               Latin America
# 4         France             France                      Europe
#
#                      city          st         sec_lvl_domn  device_type  \
# 0                 SLIDELL   LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                   TOKYO       TOKYO           MOPERA.NET       TABLET
# 2               ELK GROVE  CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3  SAO FRANCISCO DE GOIAS       GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4                  BEZONS  VAL-D'OISE           PROXAD.NET  MOBILEPHONE
#
#   operating_sys                                            ip_addr  \
# 0    IOS_12.1.4  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1   ANDROID_6.0  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2    IOS_12.1.2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3   ANDROID_6.0  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4     ANDROID_9  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
#
#                                           user_agent  VISIT  ENGD_VISIT  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...      1           0
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...      1           0
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...      1           0
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...      1           0
#
#    VIEWS                                           page_url  wk  mth    yr  \
# 0      1                        www.ibm.com/watson/campaign  11    3  2019
# 1      1                          www.ibm.com/privacy/us/en  11    3  2019
# 2      1  www.ibm.com/account/reg/us-en/signup?formid=ur...  11    3  2019
# 3      1  www.ibm.com/analytics/br/pt/business-intelligence  11    3  2019
# 4      1                           www.ibm.com/watson/fr-fr  11    3  2019
#
#                   page_vw_ts  day
# 0 2019-06-04 05:05:18.023100  1.0
# 1 2019-06-04 05:07:11.014300  1.0
# 2 2019-06-04 05:08:46.081900  1.0
# 3 2019-06-04 05:07:22.033300  1.0
# 4 2019-06-04 05:05:27.027700  1.0

# %%
#Let's see the trend of year,month and day
df['year']=df.page_vw_ts.dt.year

# %%
df.head()
# Out:
#        ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0  United States      United States               North America
# 1          Japan              Japan                       Japan
# 2  United States      United States               North America
# 3         Brazil             Brazil               Latin America
# 4         France             France                      Europe
#
#                      city          st         sec_lvl_domn  device_type  \
# 0                 SLIDELL   LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                   TOKYO       TOKYO           MOPERA.NET       TABLET
# 2               ELK GROVE  CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3  SAO FRANCISCO DE GOIAS       GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4                  BEZONS  VAL-D'OISE           PROXAD.NET  MOBILEPHONE
#
#   operating_sys                                            ip_addr  \
# 0    IOS_12.1.4  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1   ANDROID_6.0  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2    IOS_12.1.2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3   ANDROID_6.0  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4     ANDROID_9  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
#
#                                           user_agent  VISIT  ENGD_VISIT  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...      1           0
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...      1           0
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...      1           0
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...      1           0
#
#    VIEWS                                           page_url  wk  mth    yr  \
# 0      1                        www.ibm.com/watson/campaign  11    3  2019
# 1      1                          www.ibm.com/privacy/us/en  11    3  2019
# 2      1  www.ibm.com/account/reg/us-en/signup?formid=ur...  11    3  2019
# 3      1  www.ibm.com/analytics/br/pt/business-intelligence  11    3  2019
# 4      1                           www.ibm.com/watson/fr-fr  11    3  2019
#
#                   page_vw_ts  day    year
# 0 2019-06-04 05:05:18.023100  1.0  2019.0
# 1 2019-06-04 05:07:11.014300  1.0  2019.0
# 2 2019-06-04 05:08:46.081900  1.0  2019.0
# 3 2019-06-04 05:07:22.033300  1.0  2019.0
# 4 2019-06-04 05:05:27.027700  1.0  2019.0

# %%
df['month']=df.page_vw_ts.dt.month

# %%
df.head()
# Out:
#        ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0  United States      United States               North America
# 1          Japan              Japan                       Japan
# 2  United States      United States               North America
# 3         Brazil             Brazil               Latin America
# 4         France             France                      Europe
#
#                      city          st         sec_lvl_domn  device_type  \
# 0                 SLIDELL   LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                   TOKYO       TOKYO           MOPERA.NET       TABLET
# 2               ELK GROVE  CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3  SAO FRANCISCO DE GOIAS       GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4                  BEZONS  VAL-D'OISE           PROXAD.NET  MOBILEPHONE
#
#   operating_sys                                            ip_addr  \
# 0    IOS_12.1.4  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1   ANDROID_6.0  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2    IOS_12.1.2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3   ANDROID_6.0  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4     ANDROID_9  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
#
#                                           user_agent  ...  ENGD_VISIT  VIEWS  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...  ...           0      1
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...  ...           0      1
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...  ...           0      1
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...  ...           0      1
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...  ...           0      1
#
#                                             page_url  wk  mth    yr  \
# 0                        www.ibm.com/watson/campaign  11    3  2019
# 1                          www.ibm.com/privacy/us/en  11    3  2019
# 2  www.ibm.com/account/reg/us-en/signup?formid=ur...  11    3  2019
# 3  www.ibm.com/analytics/br/pt/business-intelligence  11    3  2019
# 4                           www.ibm.com/watson/fr-fr  11    3  2019
#
#                   page_vw_ts  day    year  month
# 0 2019-06-04 05:05:18.023100  1.0  2019.0    6.0
# 1 2019-06-04 05:07:11.014300  1.0  2019.0    6.0
# 2 2019-06-04 05:08:46.081900  1.0  2019.0    6.0
# 3 2019-06-04 05:07:22.033300  1.0  2019.0    6.0
# 4 2019-06-04 05:05:27.027700  1.0  2019.0    6.0
#
# [5 rows x 21 columns]

# %%
df.year.value_counts().sort_index().plot()

# %%
df.month.value_counts().sort_index().plot()

# %%
df.day.value_counts().sort_index().plot()

# %% [markdown]
# * as shown in above we can see the value of most of the year counts are 2019.
# * the most of the month counts are  6.
# * the most of the day counts are 1.

# %%
df.head()
# Out:
#        ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0  United States      United States               North America
# 1          Japan              Japan                       Japan
# 2  United States      United States               North America
# 3         Brazil             Brazil               Latin America
# 4         France             France                      Europe
#
#                      city          st         sec_lvl_domn  device_type  \
# 0                 SLIDELL   LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                   TOKYO       TOKYO           MOPERA.NET       TABLET
# 2               ELK GROVE  CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3  SAO FRANCISCO DE GOIAS       GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4                  BEZONS  VAL-D'OISE           PROXAD.NET  MOBILEPHONE
#
#   operating_sys                                            ip_addr  \
# 0    IOS_12.1.4  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1   ANDROID_6.0  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2    IOS_12.1.2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3   ANDROID_6.0  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4     ANDROID_9  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
#
#                                           user_agent  ...  ENGD_VISIT  VIEWS  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...  ...           0      1
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...  ...           0      1
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...  ...           0      1
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...  ...           0      1
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...  ...           0      1
#
#                                             page_url  wk  mth    yr  \
# 0                        www.ibm.com/watson/campaign  11    3  2019
# 1                          www.ibm.com/privacy/us/en  11    3  2019
# 2  www.ibm.com/account/reg/us-en/signup?formid=ur...  11    3  2019
# 3  www.ibm.com/analytics/br/pt/business-intelligence  11    3  2019
# 4                           www.ibm.com/watson/fr-fr  11    3  2019
#
#                   page_vw_ts  day    year  month
# 0 2019-06-04 05:05:18.023100  1.0  2019.0    6.0
# 1 2019-06-04 05:07:11.014300  1.0  2019.0    6.0
# 2 2019-06-04 05:08:46.081900  1.0  2019.0    6.0
# 3 2019-06-04 05:07:22.033300  1.0  2019.0    6.0
# 4 2019-06-04 05:05:27.027700  1.0  2019.0    6.0
#
# [5 rows x 21 columns]

# %%
df.corr()
# Out:
#                VISIT  ENGD_VISIT     VIEWS  wk  mth  yr       day      year  \
# VISIT       1.000000    0.695134  0.763486 NaN  NaN NaN -0.000425  0.000184
# ENGD_VISIT  0.695134    1.000000  0.586290 NaN  NaN NaN -0.000463  0.000163
# VIEWS       0.763486    0.586290  1.000000 NaN  NaN NaN -0.001039  0.000376
# wk               NaN         NaN       NaN NaN  NaN NaN       NaN       NaN
# mth              NaN         NaN       NaN NaN  NaN NaN       NaN       NaN
# yr               NaN         NaN       NaN NaN  NaN NaN       NaN       NaN
# day        -0.000425   -0.000463 -0.001039 NaN  NaN NaN  1.000000 -0.233142
# year        0.000184    0.000163  0.000376 NaN  NaN NaN -0.233142  1.000000
# month       0.000143    0.000446  0.000169 NaN  NaN NaN -0.025600 -0.204084
#
#                month
# VISIT       0.000143
# ENGD_VISIT  0.000446
# VIEWS       0.000169
# wk               NaN
# mth              NaN
# yr               NaN
# day        -0.025600
# year       -0.204084
# month       1.000000

# %%
# lets's drop wk,mth,yr as it contins most of the null values and does not play any important role
df.drop('wk',axis=1,inplace=True)

# %%
df.drop('mth',axis=1,inplace=True)
df.drop('yr',axis=1,inplace=True)

# %%
df.head()
# Out:
#        ctry_name intgrtd_mngmt_name intgrtd_operating_team_name  \
# 0  United States      United States               North America
# 1          Japan              Japan                       Japan
# 2  United States      United States               North America
# 3         Brazil             Brazil               Latin America
# 4         France             France                      Europe
#
#                      city          st         sec_lvl_domn  device_type  \
# 0                 SLIDELL   LOUISIANA          CHARTER.COM  MOBILEPHONE
# 1                   TOKYO       TOKYO           MOPERA.NET       TABLET
# 2               ELK GROVE  CALIFORNIA  COMCASTBUSINESS.NET  MOBILEPHONE
# 3  SAO FRANCISCO DE GOIAS       GOIAS       VIVOZAP.COM.BR  MOBILEPHONE
# 4                  BEZONS  VAL-D'OISE           PROXAD.NET  MOBILEPHONE
#
#   operating_sys                                            ip_addr  \
# 0    IOS_12.1.4  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1   ANDROID_6.0  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2    IOS_12.1.2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3   ANDROID_6.0  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4     ANDROID_9  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
#
#                                           user_agent  VISIT  ENGD_VISIT  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...      1           0
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...      1           0
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...      1           0
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...      1           0
#
#    VIEWS                                           page_url  \
# 0      1                        www.ibm.com/watson/campaign
# 1      1                          www.ibm.com/privacy/us/en
# 2      1  www.ibm.com/account/reg/us-en/signup?formid=ur...
# 3      1  www.ibm.com/analytics/br/pt/business-intelligence
# 4      1                           www.ibm.com/watson/fr-fr
#
#                   page_vw_ts  day    year  month
# 0 2019-06-04 05:05:18.023100  1.0  2019.0    6.0
# 1 2019-06-04 05:07:11.014300  1.0  2019.0    6.0
# 2 2019-06-04 05:08:46.081900  1.0  2019.0    6.0
# 3 2019-06-04 05:07:22.033300  1.0  2019.0    6.0
# 4 2019-06-04 05:05:27.027700  1.0  2019.0    6.0

# %%
# lets's drop some more columns that are irrelevant to our data means if they dont be in data set it will not affect our analysis.
df.drop('intgrtd_mngmt_name',axis=1,inplace=True)
df.drop('intgrtd_operating_team_name',axis=1,inplace=True)
df.drop('st',axis=1,inplace=True)
df.drop('sec_lvl_domn',axis=1,inplace=True)
df.drop('device_type',axis=1,inplace=True)

# %%
df.head()
# Out:
#        ctry_name                    city operating_sys  \
# 0  United States                 SLIDELL    IOS_12.1.4
# 1          Japan                   TOKYO   ANDROID_6.0
# 2  United States               ELK GROVE    IOS_12.1.2
# 3         Brazil  SAO FRANCISCO DE GOIAS   ANDROID_6.0
# 4         France                  BEZONS     ANDROID_9
#
#                                              ip_addr  \
# 0  287e8e9aeedb50e963906f10cca7ca26ae830154e69220...
# 1  d7746df5cc2de7f79584d57c2c082b9acc7697602021a1...
# 2  8540464f5f376c7a160d63632f8cbedc96c61158daf9ae...
# 3  cb9ffa7be250fc62426a431a4f08bc0c8222f63514ba39...
# 4  7ce278be1b02a0253cc0219fa9ceddfe8e91846be343a4...
#
#                                           user_agent  VISIT  ENGD_VISIT  \
# 0  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_4 LIKE...      1           0
# 1  MOZILLA/5.0 (LINUX; ANDROID 6.0; D-01J BUILD/H...      1           0
# 2  MOZILLA/5.0 (IPHONE; CPU IPHONE OS 12_1_2 LIKE...      1           0
# 3  MOZILLA/5.0 (LINUX; ANDROID 6.0; PT-BR; 5010E ...      1           0
# 4  MOZILLA/5.0 (LINUX; ANDROID 9; SM-G965F BUILD/...      1           0
#
#    VIEWS                                           page_url  \
# 0      1                        www.ibm.com/watson/campaign
# 1      1                          www.ibm.com/privacy/us/en
# 2      1  www.ibm.com/account/reg/us-en/signup?formid=ur...
# 3      1  www.ibm.com/analytics/br/pt/business-intelligence
# 4      1                           www.ibm.com/watson/fr-fr
#
#                   page_vw_ts  day    year  month
# 0 2019-06-04 05:05:18.023100  1.0  2019.0    6.0
# 1 2019-06-04 05:07:11.014300  1.0  2019.0    6.0
# 2 2019-06-04 05:08:46.081900  1.0  2019.0    6.0
# 3 2019-06-04 05:07:22.033300  1.0  2019.0    6.0
# 4 2019-06-04 05:05:27.027700  1.0  2019.0    6.0

# %%
df.isnull().sum()
# Out:
# ctry_name            0
# city             46586
# operating_sys     1820
# ip_addr              0
# user_agent           6
# VISIT                0
# ENGD_VISIT           0
# VIEWS                0
# page_url             1
# page_vw_ts        2743
# day               2743
# year              2743
# month             2743
# dtype: int64

# %%
df['city'].fillna((df['city'].mode()[0]),inplace=True)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# ctry_name        0
# city             0
# operating_sys    0
# ip_addr          0
# user_agent       0
# VISIT            0
# ENGD_VISIT       0
# VIEWS            0
# page_url         0
# page_vw_ts       0
# day              0
# year             0
# month            0
# dtype: int64

# %%
sns.pairplot(df)

# %% [markdown]
# * from above we can say that the VIEWS and VISITS have the linear Relationship.
# * in months most of the values are at 6.
# * in day the values are at 1.

# %%
plt.figure(figsize=[10,5])
plt.subplot(1,2,1)
sns.scatterplot(df.VIEWS,df.day,color='r')
sns.scatterplot(df.VIEWS,df.VISIT,color='g')
sns.scatterplot(df.VISIT,df.ENGD_VISIT,color='b')

plt.subplot(1,2,2)
sns.scatterplot(df.VIEWS,df.month,color='r')
sns.scatterplot(df.VIEWS,df.VISIT,color='g')
sns.scatterplot(df.VISIT,df.ENGD_VISIT,color='b')

# %%
df.pivot_table(['VISIT','VIEWS','ENGD_VISIT'],('day')).plot(kind='bar')

# %%
df.pivot_table(['VISIT','VIEWS','ENGD_VISIT'],('month')).plot(kind='bar')

# %%
data=df.pivot_table(['VISIT','VIEWS','ENGD_VISIT','day','month'],('ip_addr'),aggfunc='sum')

# %%
data
# Out:
#                                                     ENGD_VISIT  VIEWS  VISIT  \
# ip_addr
# 00000bfd838fedd4c2adff293a64d5efa3406b27053a102...           0      4      4
# 00002f7fddaa273634e38ec7004224498baa7a46cf26407...           0      2      2
# 0000694257f2882ccebb6a5431a8ebca19063252492891f...           0      1      1
# 0000a229c86f8baa193ffdcf9c2a88f83a91b9faad73f72...           0      2      2
# 0000faf7927142fa7fbc189d4a1bf23e4eb0c8d3b49c622...           0      1      1
# 0000ffd994e88c4976eaffa1537ab48ca89ebc038cd7ed2...           1      1      1
# 000113ae720213780c4cf1709aba0919b45b758e06c6493...           0      1      1
# 00011820825268e9b258fc1a9b27b4ac1766bb8c49b319e...           1      2      1
# 0001285b0b1515cc602598e868137c652d4bdfbc4486b24...           0      1      1
# 00013c086290a02d8be6063bd7b4f17b629bf4014adb998...           0      1      1
# 000140c4ddf2092a5beb80f06bb38995df58d0c753807fe...           1      5      2
# 000150e627c2fcae615846141fcd15bf05617618d82e392...           0      2      2
# 0001a81526e27b98a4a4f274078c5137da3b82dd938c41f...           0      1      1
# 0001b76a8f0607d412918ec110796b6868701fd25085177...           0      1      1
# 0001dc097443829d36fda634cca26b6f0f1b8251990ac93...           0      1      1
# 0002361095df621e28423283d6a699e0eec734bfaf7f9b6...           0      1      1
# 000249cba414b5a08d397c1c117be3219397ded53824ac1...           0      1      1
# 000291c602c68a6e59bd8f801e7ac3852fedddedefa79db...           0      1      1
# 000297bbf10428ed3b3e91faddb78d0d6ae30f44d4f52fa...           2      4      2
# 00029b1f67aac39f5a0ca464a2495a7adad1b6c4f1d7c5c...           0      1      1
# 0002cb7ad8a1eaef6f5c899525cab8b006a0d448a5a8783...           0      1      1
# 0002dd491cfa1ce024af355e94581ca48c581214f0dd711...           0      1      1
# 0002e4a827e7765d59a7a840c3071d98323f5b71bff90d4...           1      2      2
# 0002eed1cd70db5379f30e07b1f11ed8752123c3a92cd79...           0      1      1
# 000303328a965e9766d274fcedc67afee1a4e4e07e6b34c...           0      1      1
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df1.VIEWS=scaler.fit_transform(df1[['VIEWS']])
df1.VISIT=scaler.fit_transform(df1[['VISIT']])
df1.ENGD_VISIT=scaler.fit_transform(df1[['ENGD_VISIT']])
df1.day=scaler.fit_transform(df1[['day']])
df1.month=scaler.fit_transform(df1[['month']])

# %%
# using k-means to make 2 cluster groups
from sklearn.cluster import KMeans
km=KMeans(n_clusters=2)

# %%
y_pred=km.fit_predict(df1)

# %%
df1['cluster']=y_pred

# %%
# For plotting the graph of cluster
p=df1[df1.cluster==0]
q=df1[df1.cluster==1]

# %%
plt.scatter(p.VISIT,p.day,color='g')
plt.scatter(p.VISIT,p.VIEWS,color='g')
plt.scatter(p.VISIT,p.ENGD_VISIT,color='g')

plt.scatter(q.VISIT,q.day,color='b')
plt.scatter(q.VISIT,q.VIEWS,color='b')
plt.scatter(q.VISIT,q.ENGD_VISIT,color='b')

plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='red')

# %%
plt.scatter(p.VISIT,p.month,color='g')
plt.scatter(p.VISIT,p.VIEWS,color='g')
plt.scatter(p.VISIT,p.ENGD_VISIT,color='g')

plt.scatter(q.VISIT,q.month,color='b')
plt.scatter(q.VISIT,q.VIEWS,color='b')
plt.scatter(q.VISIT,q.ENGD_VISIT,color='b')

plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='red')

# %% [markdown]
# * Reds are the Center point for K
# * Blues are the BOTS
# * Greens are the Humans

# %%
data['BOT']=y_pred

# %%
data[data.BOT==1]
# Out:
#                                                     ENGD_VISIT  VIEWS  VISIT  \
# ip_addr
# 00099b9633602eacab5e5dbe6f33bef809352883993334b...          15    143    133
# 006fce7b2ba8352d4b2a9efe18475fb017e1bc0c78f6e6c...          44    183    117
# 01250e1a334e6fc815c8b4cb0203ec0dc6420868ef804b7...          33    136    101
# 01c754b2593e4b4af8240bc334b9dd202f8c95c5dafe317...          26    121     81
# 01dbbaff14cf4756f27f4a5250bf5f861fa58937207f881...          31    125     65
# 01ed20dd606cb2e8fb0c54282a8f52531fcb315122e14d1...          31    197    130
# 021f5543dab749dc5d0bc162109961e196df4c4922356bf...          88    298    232
# 0256f39f331abb972ba277858bb7a3abc38d7ecf2a93aac...          46    174    130
# 02a3a0b315a8a559b7dfe7023a880c94b4175e3b59f3b26...          40    197    156
# 02b60cd860068ca6e29a963c2324a8314f73f0ddcf019e7...          44    156    120
# 02edce9ed1afd43cd5a81129b20389abc88693ae3cf196a...          91    297    211
# 02ff872c88104cc974aa3be64d1ae423bed10c98b04760e...          31     95     84
# 0306d59fba6394d1c9db66abcfba4bb29e0034cbdb5ab72...          26    185    153
# 035dfa38b15d574a0503bb6aa56c5a990cb936440ac7536...          56    143     82
# 038fbe1a6feae93d88521623fa23c99161b8ded07a882d7...          34    129    102
